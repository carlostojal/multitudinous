# %% [markdown]
# # Image encoding benchmark
#
# Visualize pretrainer results on a given image and measure the encoding time.
#
# First, load the FP32 model:

# %%
import sys
sys.path.append("../")
from multitudinous.utils.model_builder import build_img_backbone
import torch

BACKBONE_VARIANT = "se_resnet50"
BATCH_SIZE = 4

# build the FP32 model
model_fp32 = build_img_backbone(BACKBONE_VARIANT, 4)
model_fp32.eval()
# Out:
# SEResNet50(
#   (conv1): Conv2d(4, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): SEBottleneckBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#       (residual): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#       (se): SqueezeAndExcitation(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=256, out_features=16, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=16, out_features=256, bias=True)
#           (3): Sigmoid()
#         )
#         (excitation): FloatFunctional(
#           (activation_post_process): Identity()
#         )
#       )
#     )
#     (1): SEBottleneckBlock(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (residual): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#       (se): SqueezeAndExcitation(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=256, out_features=16, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=16, out_features=256, bias=True)
#           (3): Sigmoid()
#         )
#         (excitation): FloatFunctional(
#           (activation_post_process): Identity()
#         )
#       )
#     )
#     (2): SEBottleneckBlock(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (residual): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#       (se): SqueezeAndExcitation(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=256, out_features=16, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=16, out_features=256, bias=True)
#           (3): Sigmoid()
#         )
#         (excitation): FloatFunctional(
#           (activation_post_process): Identity()
#         )
#       )
#     )
#   )
#   (layer2): Sequential(
#     (0): SEBottleneckBlock(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#       (residual): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#       (se): SqueezeAndExcitation(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=512, out_features=32, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=32, out_features=512, bias=True)
#           (3): Sigmoid()
#         )
#         (excitation): FloatFunctional(
#           (activation_post_process): Identity()
#         )
#       )
#     )
#     (1): SEBottleneckBlock(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (residual): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#       (se): SqueezeAndExcitation(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=512, out_features=32, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=32, out_features=512, bias=True)
#           (3): Sigmoid()
#         )
#         (excitation): FloatFunctional(
#           (activation_post_process): Identity()
#         )
#       )
#     )
#     (2): SEBottleneckBlock(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (residual): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#       (se): SqueezeAndExcitation(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=512, out_features=32, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=32, out_features=512, bias=True)
#           (3): Sigmoid()
#         )
#         (excitation): FloatFunctional(
#           (activation_post_process): Identity()
#         )
#       )
#     )
#     (3): SEBottleneckBlock(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (residual): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#       (se): SqueezeAndExcitation(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=512, out_features=32, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=32, out_features=512, bias=True)
#           (3): Sigmoid()
#         )
#         (excitation): FloatFunctional(
#           (activation_post_process): Identity()
#         )
#       )
#     )
#   )
#   (layer3): Sequential(
#     (0): SEBottleneckBlock(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#       (residual): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#       (se): SqueezeAndExcitation(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=1024, out_features=64, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=64, out_features=1024, bias=True)
#           (3): Sigmoid()
#         )
#         (excitation): FloatFunctional(
#           (activation_post_process): Identity()
#         )
#       )
#     )
#     (1): SEBottleneckBlock(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (residual): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#       (se): SqueezeAndExcitation(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=1024, out_features=64, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=64, out_features=1024, bias=True)
#           (3): Sigmoid()
#         )
#         (excitation): FloatFunctional(
#           (activation_post_process): Identity()
#         )
#       )
#     )
#     (2): SEBottleneckBlock(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (residual): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#       (se): SqueezeAndExcitation(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=1024, out_features=64, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=64, out_features=1024, bias=True)
#           (3): Sigmoid()
#         )
#         (excitation): FloatFunctional(
#           (activation_post_process): Identity()
#         )
#       )
#     )
#     (3): SEBottleneckBlock(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (residual): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#       (se): SqueezeAndExcitation(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=1024, out_features=64, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=64, out_features=1024, bias=True)
#           (3): Sigmoid()
#         )
#         (excitation): FloatFunctional(
#           (activation_post_process): Identity()
#         )
#       )
#     )
#     (4): SEBottleneckBlock(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (residual): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#       (se): SqueezeAndExcitation(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=1024, out_features=64, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=64, out_features=1024, bias=True)
#           (3): Sigmoid()
#         )
#         (excitation): FloatFunctional(
#           (activation_post_process): Identity()
#         )
#       )
#     )
#     (5): SEBottleneckBlock(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (residual): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#       (se): SqueezeAndExcitation(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=1024, out_features=64, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=64, out_features=1024, bias=True)
#           (3): Sigmoid()
#         )
#         (excitation): FloatFunctional(
#           (activation_post_process): Identity()
#         )
#       )
#     )
#   )
#   (layer4): Sequential(
#     (0): SEBottleneckBlock(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#       (residual): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#       (se): SqueezeAndExcitation(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=2048, out_features=128, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=128, out_features=2048, bias=True)
#           (3): Sigmoid()
#         )
#         (excitation): FloatFunctional(
#           (activation_post_process): Identity()
#         )
#       )
#     )
#     (1): SEBottleneckBlock(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (residual): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#       (se): SqueezeAndExcitation(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=2048, out_features=128, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=128, out_features=2048, bias=True)
#           (3): Sigmoid()
#         )
#         (excitation): FloatFunctional(
#           (activation_post_process): Identity()
#         )
#       )
#     )
#     (2): SEBottleneckBlock(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (residual): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#       (se): SqueezeAndExcitation(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=2048, out_features=128, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=128, out_features=2048, bias=True)
#           (3): Sigmoid()
#         )
#         (excitation): FloatFunctional(
#           (activation_post_process): Identity()
#         )
#       )
#     )
#     (3): SEBottleneckBlock(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (residual): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#       (se): SqueezeAndExcitation(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=2048, out_features=128, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=128, out_features=2048, bias=True)
#           (3): Sigmoid()
#         )
#         (excitation): FloatFunctional(
#           (activation_post_process): Identity()
#         )
#       )
#     )
#     (4): SEBottleneckBlock(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (residual): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#       (se): SqueezeAndExcitation(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=2048, out_features=128, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=128, out_features=2048, bias=True)
#           (3): Sigmoid()
#         )
#         (excitation): FloatFunctional(
#           (activation_post_process): Identity()
#         )
#       )
#     )
#     (5): SEBottleneckBlock(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (residual): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#       (se): SqueezeAndExcitation(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=2048, out_features=128, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=128, out_features=2048, bias=True)
#           (3): Sigmoid()
#         )
#         (excitation): FloatFunctional(
#           (activation_post_process): Identity()
#         )
#       )
#     )
#     (6): SEBottleneckBlock(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (residual): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#       (se): SqueezeAndExcitation(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=2048, out_features=128, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=128, out_features=2048, bias=True)
#           (3): Sigmoid()
#         )
#         (excitation): FloatFunctional(
#           (activation_post_process): Identity()
#         )
#       )
#     )
#     (7): SEBottleneckBlock(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (residual): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#       (se): SqueezeAndExcitation(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=2048, out_features=128, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=128, out_features=2048, bias=True)
#           (3): Sigmoid()
#         )
#         (excitation): FloatFunctional(
#           (activation_post_process): Identity()
#         )
#       )
#     )
#   )
#   (quant): QuantStub()
#   (dequant): DeQuantStub()
# )

# %% [markdown]
# Now, quantize the model:

# %%
from multitudinous.utils.quantization import get_quantized_model

model_q = get_quantized_model(model_fp32, 'x86')
model_q.load_state_dict(torch.load("../se_resnet_q/se_resnet50_quantized.pth"))
model_q.eval()
# Out:
# /home/carlostojal/anaconda3/envs/multitudinous/lib/python3.12/site-packages/torch/ao/quantization/observer.py:220: UserWarning: Please use quant_min and quant_max to specify the range for observers.                     reduce_range will be deprecated in a future release of PyTorch.
#   warnings.warn(
# /home/carlostojal/anaconda3/envs/multitudinous/lib/python3.12/site-packages/torch/ao/quantization/observer.py:1263: UserWarning: must run observer before calling calculate_qparams.                                    Returning default scale and zero point
#   warnings.warn(
# SEResNet50(
#   (conv1): QuantizedConv2d(4, 64, kernel_size=(7, 7), stride=(2, 2), scale=0.03663778305053711, zero_point=74, padding=(3, 3), bias=False)
#   (bn1): QuantizedBatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): SEBottleneckBlock(
#       (conv1): QuantizedConv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), scale=0.09296398609876633, zero_point=61, bias=False)
#       (bn1): QuantizedBatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): QuantizedConv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), scale=0.27597540616989136, zero_point=57, padding=(1, 1), bias=False)
#       (bn2): QuantizedBatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): QuantizedConv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), scale=0.07651639729738235, zero_point=60, bias=False)
#       (bn3): QuantizedBatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): QuantizedConv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), scale=0.08636872470378876, zero_point=63, bias=False)
#         (1): QuantizedBatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#       (residual): QFunctional(
#         scale=0.10657025128602982, zero_point=56
#         (activation_post_process): Identity()
#       )
#       (se): SqueezeAndExcitation(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): QuantizedLinear(in_features=256, out_features=16, scale=0.009692694991827011, zero_point=74, qscheme=torch.per_channel_affine)
#           (1): ReLU()
#           (2): QuantizedLinear(in_features=16, out_features=256, scale=0.00729344179853797, zero_point=61, qscheme=torch.per_channel_affine)
#           (3): Sigmoid()
#         )
#         (excitation): QFunctional(
#           scale=0.05678868666291237, zero_point=63
#           (activation_post_process): Identity()
#         )
#       )
#     )
#     (1): SEBottleneckBlock(
#       (conv1): QuantizedConv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), scale=0.16616523265838623, zero_point=54, bias=False)
#       (bn1): QuantizedBatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): QuantizedConv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), scale=0.5298929214477539, zero_point=50, padding=(1, 1), bias=False)
#       (bn2): QuantizedBatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): QuantizedConv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), scale=0.11246772855520248, zero_point=58, bias=False)
#       (bn3): QuantizedBatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (residual): QFunctional(
#         scale=0.12216996401548386, zero_point=41
#         (activation_post_process): Identity()
#       )
#       (se): SqueezeAndExcitation(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): QuantizedLinear(in_features=256, out_features=16, scale=0.02426479570567608, zero_point=44, qscheme=torch.per_channel_affine)
#           (1): ReLU()
#           (2): QuantizedLinear(in_features=16, out_features=256, scale=0.016867607831954956, zero_point=61, qscheme=torch.per_channel_affine)
#           (3): Sigmoid()
#         )
#         (excitation): QFunctional(
#           scale=0.0817607119679451, zero_point=60
#           (activation_post_process): Identity()
#         )
#       )
#     )
#     (2): SEBottleneckBlock(
#       (conv1): QuantizedConv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), scale=0.29952389001846313, zero_point=66, bias=False)
#       (bn1): QuantizedBatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): QuantizedConv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), scale=0.6418001055717468, zero_point=69, padding=(1, 1), bias=False)
#       (bn2): QuantizedBatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): QuantizedConv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), scale=0.12733925879001617, zero_point=62, bias=False)
#       (bn3): QuantizedBatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (residual): QFunctional(
#         scale=0.1589917689561844, zero_point=38
#         (activation_post_process): Identity()
#       )
#       (se): SqueezeAndExcitation(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): QuantizedLinear(in_features=256, out_features=16, scale=0.04356130212545395, zero_point=62, qscheme=torch.per_channel_affine)
#           (1): ReLU()
#           (2): QuantizedLinear(in_features=16, out_features=256, scale=0.027231493964791298, zero_point=65, qscheme=torch.per_channel_affine)
#           (3): Sigmoid()
#         )
#         (excitation): QFunctional(
#           scale=0.10210137069225311, zero_point=60
#           (activation_post_process): Identity()
#         )
#       )
#     )
#   )
#   (layer2): Sequential(
#     (0): SEBottleneckBlock(
#       (conv1): QuantizedConv2d(256, 128, kernel_size=(1, 1), stride=(2, 2), scale=0.3505752980709076, zero_point=49, bias=False)
#       (bn1): QuantizedBatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): QuantizedConv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), scale=1.1402621269226074, zero_point=62, padding=(1, 1), bias=False)
#       (bn2): QuantizedBatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): QuantizedConv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), scale=0.2791822552680969, zero_point=65, bias=False)
#       (bn3): QuantizedBatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): QuantizedConv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), scale=0.33479321002960205, zero_point=65, bias=False)
#         (1): QuantizedBatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#       (residual): QFunctional(
#         scale=0.26286113262176514, zero_point=62
#         (activation_post_process): Identity()
#       )
#       (se): SqueezeAndExcitation(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): QuantizedLinear(in_features=512, out_features=32, scale=0.0409187488257885, zero_point=65, qscheme=torch.per_channel_affine)
#           (1): ReLU()
#           (2): QuantizedLinear(in_features=32, out_features=512, scale=0.014309749938547611, zero_point=69, qscheme=torch.per_channel_affine)
#           (3): Sigmoid()
#         )
#         (excitation): QFunctional(
#           scale=0.12081069499254227, zero_point=66
#           (activation_post_process): Identity()
#         )
#       )
#     )
#     (1): SEBottleneckBlock(
#       (conv1): QuantizedConv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), scale=0.8340198397636414, zero_point=46, bias=False)
#       (bn1): QuantizedBatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): QuantizedConv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), scale=1.21392023563385, zero_point=52, padding=(1, 1), bias=False)
#       (bn2): QuantizedBatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): QuantizedConv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), scale=0.32770490646362305, zero_point=68, bias=False)
#       (bn3): QuantizedBatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (residual): QFunctional(
#         scale=0.2837732136249542, zero_point=44
#         (activation_post_process): Identity()
#       )
#       (se): SqueezeAndExcitation(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): QuantizedLinear(in_features=512, out_features=32, scale=0.12319191545248032, zero_point=45, qscheme=torch.per_channel_affine)
#           (1): ReLU()
#           (2): QuantizedLinear(in_features=32, out_features=512, scale=0.05779876559972763, zero_point=68, qscheme=torch.per_channel_affine)
#           (3): Sigmoid()
#         )
#         (excitation): QFunctional(
#           scale=0.2072627693414688, zero_point=65
#           (activation_post_process): Identity()
#         )
#       )
#     )
#     (2): SEBottleneckBlock(
#       (conv1): QuantizedConv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), scale=0.7030125260353088, zero_point=60, bias=False)
#       (bn1): QuantizedBatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): QuantizedConv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), scale=0.47258731722831726, zero_point=65, padding=(1, 1), bias=False)
#       (bn2): QuantizedBatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): QuantizedConv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), scale=0.11157301813364029, zero_point=66, bias=False)
#       (bn3): QuantizedBatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (residual): QFunctional(
#         scale=0.21809479594230652, zero_point=13
#         (activation_post_process): Identity()
#       )
#       (se): SqueezeAndExcitation(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): QuantizedLinear(in_features=512, out_features=32, scale=0.015582293272018433, zero_point=102, qscheme=torch.per_channel_affine)
#           (1): ReLU()
#           (2): QuantizedLinear(in_features=32, out_features=512, scale=0.0047016325406730175, zero_point=66, qscheme=torch.per_channel_affine)
#           (3): Sigmoid()
#         )
#         (excitation): QFunctional(
#           scale=0.04267324507236481, zero_point=68
#           (activation_post_process): Identity()
#         )
#       )
#     )
#     (3): SEBottleneckBlock(
#       (conv1): QuantizedConv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), scale=1.0128841400146484, zero_point=58, bias=False)
#       (bn1): QuantizedBatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): QuantizedConv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), scale=1.0203182697296143, zero_point=50, padding=(1, 1), bias=False)
#       (bn2): QuantizedBatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): QuantizedConv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), scale=0.20916339755058289, zero_point=69, bias=False)
#       (bn3): QuantizedBatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (residual): QFunctional(
#         scale=0.28125131130218506, zero_point=33
#         (activation_post_process): Identity()
#       )
#       (se): SqueezeAndExcitation(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): QuantizedLinear(in_features=512, out_features=32, scale=0.136454239487648, zero_point=86, qscheme=torch.per_channel_affine)
#           (1): ReLU()
#           (2): QuantizedLinear(in_features=32, out_features=512, scale=0.029615405946969986, zero_point=72, qscheme=torch.per_channel_affine)
#           (3): Sigmoid()
#         )
#         (excitation): QFunctional(
#           scale=0.12354426831007004, zero_point=72
#           (activation_post_process): Identity()
#         )
#       )
#     )
#   )
#   (layer3): Sequential(
#     (0): SEBottleneckBlock(
#       (conv1): QuantizedConv2d(512, 256, kernel_size=(1, 1), stride=(2, 2), scale=1.0239554643630981, zero_point=60, bias=False)
#       (bn1): QuantizedBatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): QuantizedConv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), scale=1.3900740146636963, zero_point=45, padding=(1, 1), bias=False)
#       (bn2): QuantizedBatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): QuantizedConv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), scale=0.4855779707431793, zero_point=57, bias=False)
#       (bn3): QuantizedBatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): QuantizedConv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), scale=0.8821147084236145, zero_point=58, bias=False)
#         (1): QuantizedBatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#       (residual): QFunctional(
#         scale=0.3492659330368042, zero_point=64
#         (activation_post_process): Identity()
#       )
#       (se): SqueezeAndExcitation(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): QuantizedLinear(in_features=1024, out_features=64, scale=0.0707898661494255, zero_point=89, qscheme=torch.per_channel_affine)
#           (1): ReLU()
#           (2): QuantizedLinear(in_features=64, out_features=1024, scale=0.02884429134428501, zero_point=72, qscheme=torch.per_channel_affine)
#           (3): Sigmoid()
#         )
#         (excitation): QFunctional(
#           scale=0.1941499412059784, zero_point=63
#           (activation_post_process): Identity()
#         )
#       )
#     )
#     (1): SEBottleneckBlock(
#       (conv1): QuantizedConv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), scale=1.0445270538330078, zero_point=55, bias=False)
#       (bn1): QuantizedBatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): QuantizedConv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), scale=1.8481937646865845, zero_point=58, padding=(1, 1), bias=False)
#       (bn2): QuantizedBatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): QuantizedConv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), scale=0.6479299664497375, zero_point=67, bias=False)
#       (bn3): QuantizedBatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (residual): QFunctional(
#         scale=0.37433692812919617, zero_point=36
#         (activation_post_process): Identity()
#       )
#       (se): SqueezeAndExcitation(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): QuantizedLinear(in_features=1024, out_features=64, scale=0.055032145231962204, zero_point=54, qscheme=torch.per_channel_affine)
#           (1): ReLU()
#           (2): QuantizedLinear(in_features=64, out_features=1024, scale=0.03216145932674408, zero_point=59, qscheme=torch.per_channel_affine)
#           (3): Sigmoid()
#         )
#         (excitation): QFunctional(
#           scale=0.21584740281105042, zero_point=63
#           (activation_post_process): Identity()
#         )
#       )
#     )
#     (2): SEBottleneckBlock(
#       (conv1): QuantizedConv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), scale=1.183863878250122, zero_point=70, bias=False)
#       (bn1): QuantizedBatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): QuantizedConv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), scale=1.7451746463775635, zero_point=64, padding=(1, 1), bias=False)
#       (bn2): QuantizedBatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): QuantizedConv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), scale=0.6720973253250122, zero_point=71, bias=False)
#       (bn3): QuantizedBatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (residual): QFunctional(
#         scale=0.4681229591369629, zero_point=35
#         (activation_post_process): Identity()
#       )
#       (se): SqueezeAndExcitation(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): QuantizedLinear(in_features=1024, out_features=64, scale=0.10257607698440552, zero_point=48, qscheme=torch.per_channel_affine)
#           (1): ReLU()
#           (2): QuantizedLinear(in_features=64, out_features=1024, scale=0.049189090728759766, zero_point=78, qscheme=torch.per_channel_affine)
#           (3): Sigmoid()
#         )
#         (excitation): QFunctional(
#           scale=0.2852029800415039, zero_point=70
#           (activation_post_process): Identity()
#         )
#       )
#     )
#     (3): SEBottleneckBlock(
#       (conv1): QuantizedConv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), scale=1.29197359085083, zero_point=57, bias=False)
#       (bn1): QuantizedBatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): QuantizedConv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), scale=2.151230812072754, zero_point=65, padding=(1, 1), bias=False)
#       (bn2): QuantizedBatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): QuantizedConv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), scale=0.6815118789672852, zero_point=68, bias=False)
#       (bn3): QuantizedBatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (residual): QFunctional(
#         scale=0.5193555355072021, zero_point=37
#         (activation_post_process): Identity()
#       )
#       (se): SqueezeAndExcitation(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): QuantizedLinear(in_features=1024, out_features=64, scale=0.09156672656536102, zero_point=61, qscheme=torch.per_channel_affine)
#           (1): ReLU()
#           (2): QuantizedLinear(in_features=64, out_features=1024, scale=0.06455911695957184, zero_point=68, qscheme=torch.per_channel_affine)
#           (3): Sigmoid()
#         )
#         (excitation): QFunctional(
#           scale=0.32260438799858093, zero_point=69
#           (activation_post_process): Identity()
#         )
#       )
#     )
#     (4): SEBottleneckBlock(
#       (conv1): QuantizedConv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), scale=1.3945353031158447, zero_point=51, bias=False)
#       (bn1): QuantizedBatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): QuantizedConv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), scale=1.9236239194869995, zero_point=57, padding=(1, 1), bias=False)
#       (bn2): QuantizedBatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): QuantizedConv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), scale=0.6157487630844116, zero_point=68, bias=False)
#       (bn3): QuantizedBatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (residual): QFunctional(
#         scale=0.5477240085601807, zero_point=38
#         (activation_post_process): Identity()
#       )
#       (se): SqueezeAndExcitation(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): QuantizedLinear(in_features=1024, out_features=64, scale=0.07827414572238922, zero_point=45, qscheme=torch.per_channel_affine)
#           (1): ReLU()
#           (2): QuantizedLinear(in_features=64, out_features=1024, scale=0.04792443662881851, zero_point=62, qscheme=torch.per_channel_affine)
#           (3): Sigmoid()
#         )
#         (excitation): QFunctional(
#           scale=0.2735580503940582, zero_point=68
#           (activation_post_process): Identity()
#         )
#       )
#     )
#     (5): SEBottleneckBlock(
#       (conv1): QuantizedConv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), scale=1.2767980098724365, zero_point=70, bias=False)
#       (bn1): QuantizedBatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): QuantizedConv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), scale=1.2901959419250488, zero_point=50, padding=(1, 1), bias=False)
#       (bn2): QuantizedBatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): QuantizedConv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), scale=0.5708981156349182, zero_point=66, bias=False)
#       (bn3): QuantizedBatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (residual): QFunctional(
#         scale=0.4760560095310211, zero_point=30
#         (activation_post_process): Identity()
#       )
#       (se): SqueezeAndExcitation(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): QuantizedLinear(in_features=1024, out_features=64, scale=0.04416988790035248, zero_point=48, qscheme=torch.per_channel_affine)
#           (1): ReLU()
#           (2): QuantizedLinear(in_features=64, out_features=1024, scale=0.03744865581393242, zero_point=73, qscheme=torch.per_channel_affine)
#           (3): Sigmoid()
#         )
#         (excitation): QFunctional(
#           scale=0.23231074213981628, zero_point=65
#           (activation_post_process): Identity()
#         )
#       )
#     )
#   )
#   (layer4): Sequential(
#     (0): SEBottleneckBlock(
#       (conv1): QuantizedConv2d(1024, 512, kernel_size=(1, 1), stride=(2, 2), scale=1.208198070526123, zero_point=58, bias=False)
#       (bn1): QuantizedBatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): QuantizedConv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), scale=2.225287437438965, zero_point=66, padding=(1, 1), bias=False)
#       (bn2): QuantizedBatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): QuantizedConv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), scale=0.516205370426178, zero_point=65, bias=False)
#       (bn3): QuantizedBatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): QuantizedConv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), scale=0.9881405830383301, zero_point=60, bias=False)
#         (1): QuantizedBatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#       (residual): QFunctional(
#         scale=0.45391541719436646, zero_point=62
#         (activation_post_process): Identity()
#       )
#       (se): SqueezeAndExcitation(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): QuantizedLinear(in_features=2048, out_features=128, scale=0.06506992131471634, zero_point=59, qscheme=torch.per_channel_affine)
#           (1): ReLU()
#           (2): QuantizedLinear(in_features=128, out_features=2048, scale=0.0369093231856823, zero_point=65, qscheme=torch.per_channel_affine)
#           (3): Sigmoid()
#         )
#         (excitation): QFunctional(
#           scale=0.22629132866859436, zero_point=60
#           (activation_post_process): Identity()
#         )
#       )
#     )
#     (1): SEBottleneckBlock(
#       (conv1): QuantizedConv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), scale=1.5203286409378052, zero_point=67, bias=False)
#       (bn1): QuantizedBatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): QuantizedConv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), scale=2.2907400131225586, zero_point=60, padding=(1, 1), bias=False)
#       (bn2): QuantizedBatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): QuantizedConv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), scale=0.5405200123786926, zero_point=55, bias=False)
#       (bn3): QuantizedBatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (residual): QFunctional(
#         scale=0.4250878095626831, zero_point=33
#         (activation_post_process): Identity()
#       )
#       (se): SqueezeAndExcitation(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): QuantizedLinear(in_features=2048, out_features=128, scale=0.06376425921916962, zero_point=63, qscheme=torch.per_channel_affine)
#           (1): ReLU()
#           (2): QuantizedLinear(in_features=128, out_features=2048, scale=0.03575799986720085, zero_point=65, qscheme=torch.per_channel_affine)
#           (3): Sigmoid()
#         )
#         (excitation): QFunctional(
#           scale=0.24061624705791473, zero_point=60
#           (activation_post_process): Identity()
#         )
#       )
#     )
#     (2): SEBottleneckBlock(
#       (conv1): QuantizedConv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), scale=1.9005155563354492, zero_point=67, bias=False)
#       (bn1): QuantizedBatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): QuantizedConv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), scale=2.1998186111450195, zero_point=52, padding=(1, 1), bias=False)
#       (bn2): QuantizedBatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): QuantizedConv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), scale=0.6331847310066223, zero_point=56, bias=False)
#       (bn3): QuantizedBatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (residual): QFunctional(
#         scale=0.4938758313655853, zero_point=27
#         (activation_post_process): Identity()
#       )
#       (se): SqueezeAndExcitation(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): QuantizedLinear(in_features=2048, out_features=128, scale=0.05284611135721207, zero_point=63, qscheme=torch.per_channel_affine)
#           (1): ReLU()
#           (2): QuantizedLinear(in_features=128, out_features=2048, scale=0.02681690827012062, zero_point=62, qscheme=torch.per_channel_affine)
#           (3): Sigmoid()
#         )
#         (excitation): QFunctional(
#           scale=0.21393656730651855, zero_point=60
#           (activation_post_process): Identity()
#         )
#       )
#     )
#     (3): SEBottleneckBlock(
#       (conv1): QuantizedConv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), scale=2.0263640880584717, zero_point=59, bias=False)
#       (bn1): QuantizedBatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): QuantizedConv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), scale=3.414234161376953, zero_point=64, padding=(1, 1), bias=False)
#       (bn2): QuantizedBatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): QuantizedConv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), scale=0.7154319882392883, zero_point=63, bias=False)
#       (bn3): QuantizedBatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (residual): QFunctional(
#         scale=0.6048092842102051, zero_point=28
#         (activation_post_process): Identity()
#       )
#       (se): SqueezeAndExcitation(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): QuantizedLinear(in_features=2048, out_features=128, scale=0.10081116110086441, zero_point=59, qscheme=torch.per_channel_affine)
#           (1): ReLU()
#           (2): QuantizedLinear(in_features=128, out_features=2048, scale=0.03955720737576485, zero_point=58, qscheme=torch.per_channel_affine)
#           (3): Sigmoid()
#         )
#         (excitation): QFunctional(
#           scale=0.282835990190506, zero_point=64
#           (activation_post_process): Identity()
#         )
#       )
#     )
#     (4): SEBottleneckBlock(
#       (conv1): QuantizedConv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), scale=2.8657193183898926, zero_point=56, bias=False)
#       (bn1): QuantizedBatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): QuantizedConv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), scale=3.268531084060669, zero_point=72, padding=(1, 1), bias=False)
#       (bn2): QuantizedBatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): QuantizedConv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), scale=0.6471567153930664, zero_point=65, bias=False)
#       (bn3): QuantizedBatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (residual): QFunctional(
#         scale=0.7075136303901672, zero_point=33
#         (activation_post_process): Identity()
#       )
#       (se): SqueezeAndExcitation(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): QuantizedLinear(in_features=2048, out_features=128, scale=0.08237776905298233, zero_point=52, qscheme=torch.per_channel_affine)
#           (1): ReLU()
#           (2): QuantizedLinear(in_features=128, out_features=2048, scale=0.038660552352666855, zero_point=64, qscheme=torch.per_channel_affine)
#           (3): Sigmoid()
#         )
#         (excitation): QFunctional(
#           scale=0.3157431185245514, zero_point=57
#           (activation_post_process): Identity()
#         )
#       )
#     )
#     (5): SEBottleneckBlock(
#       (conv1): QuantizedConv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), scale=2.6298744678497314, zero_point=54, bias=False)
#       (bn1): QuantizedBatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): QuantizedConv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), scale=3.1185789108276367, zero_point=57, padding=(1, 1), bias=False)
#       (bn2): QuantizedBatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): QuantizedConv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), scale=0.3959014117717743, zero_point=59, bias=False)
#       (bn3): QuantizedBatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (residual): QFunctional(
#         scale=0.6886743307113647, zero_point=21
#         (activation_post_process): Identity()
#       )
#       (se): SqueezeAndExcitation(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): QuantizedLinear(in_features=2048, out_features=128, scale=0.07499352097511292, zero_point=68, qscheme=torch.per_channel_affine)
#           (1): ReLU()
#           (2): QuantizedLinear(in_features=128, out_features=2048, scale=0.03204426169395447, zero_point=65, qscheme=torch.per_channel_affine)
#           (3): Sigmoid()
#         )
#         (excitation): QFunctional(
#           scale=0.24180488288402557, zero_point=56
#           (activation_post_process): Identity()
#         )
#       )
#     )
#     (6): SEBottleneckBlock(
#       (conv1): QuantizedConv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), scale=4.31789493560791, zero_point=52, bias=False)
#       (bn1): QuantizedBatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): QuantizedConv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), scale=3.4370462894439697, zero_point=66, padding=(1, 1), bias=False)
#       (bn2): QuantizedBatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): QuantizedConv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), scale=0.7119536995887756, zero_point=73, bias=False)
#       (bn3): QuantizedBatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (residual): QFunctional(
#         scale=0.77734375, zero_point=21
#         (activation_post_process): Identity()
#       )
#       (se): SqueezeAndExcitation(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): QuantizedLinear(in_features=2048, out_features=128, scale=0.08727976679801941, zero_point=55, qscheme=torch.per_channel_affine)
#           (1): ReLU()
#           (2): QuantizedLinear(in_features=128, out_features=2048, scale=0.04654601216316223, zero_point=57, qscheme=torch.per_channel_affine)
#           (3): Sigmoid()
#         )
#         (excitation): QFunctional(
#           scale=0.2801766097545624, zero_point=64
#           (activation_post_process): Identity()
#         )
#       )
#     )
#     (7): SEBottleneckBlock(
#       (conv1): QuantizedConv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), scale=5.040639877319336, zero_point=49, bias=False)
#       (bn1): QuantizedBatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): QuantizedConv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), scale=3.701751470565796, zero_point=52, padding=(1, 1), bias=False)
#       (bn2): QuantizedBatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): QuantizedConv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), scale=0.925929605960846, zero_point=54, bias=False)
#       (bn3): QuantizedBatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (residual): QFunctional(
#         scale=0.8372700810432434, zero_point=24
#         (activation_post_process): Identity()
#       )
#       (se): SqueezeAndExcitation(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): QuantizedLinear(in_features=2048, out_features=128, scale=0.08839432895183563, zero_point=64, qscheme=torch.per_channel_affine)
#           (1): ReLU()
#           (2): QuantizedLinear(in_features=128, out_features=2048, scale=0.04464315250515938, zero_point=63, qscheme=torch.per_channel_affine)
#           (3): Sigmoid()
#         )
#         (excitation): QFunctional(
#           scale=0.3556821942329407, zero_point=60
#           (activation_post_process): Identity()
#         )
#       )
#     )
#   )
#   (quant): Quantize(scale=tensor([0.0078]), zero_point=tensor([0]), dtype=torch.quint8)
#   (dequant): DeQuantize()
# )

# %% [markdown]
# Now, create the dataset and dataloader instances:

# %%
from multitudinous.utils.dataset_builder import build_img_dataset

# build the dataset
dataset = build_img_dataset("tum_rgbd", "../../data/tum_rgbd1")
# create the dataloader
dataloader = torch.utils.data.DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True)

# %% [markdown]
# Now, run inference on a given image:

# %%
import time

NUM_BENCHMARKING_SAMPLES=100
NUM_WARMUP_SAMPLES=10

# metrics
total_imgs = len(dataset)
total_elapsed_time = 0
curr_sample = 0
avg_encoding_time = 0

for rgb, depth in dataloader:

    depth = depth.unsqueeze(1)
    rgbd = torch.cat((rgb, depth), dim=1)

    # run inference
    with torch.no_grad():
        start = time.time()
        output = model_q(rgbd)
        end = time.time()
        encoding_time = (end - start) * 1000

    curr_sample += 1

    if curr_sample > NUM_WARMUP_SAMPLES:

        total_elapsed_time += encoding_time

        avg_encoding_time = total_elapsed_time/(curr_sample-NUM_WARMUP_SAMPLES)/BATCH_SIZE

        print(f"\rSample {curr_sample-NUM_WARMUP_SAMPLES}/{NUM_BENCHMARKING_SAMPLES} - Avg. encoding time: {avg_encoding_time} ms", end=" ")

    if curr_sample-NUM_WARMUP_SAMPLES == NUM_BENCHMARKING_SAMPLES:
        break

print(f"\n\n** QUANTIZED {BACKBONE_VARIANT} METRICS (CPU) **")
print(f"Avg. encoding time: {avg_encoding_time} ms")
print(f"Avg. throughput: {1/(avg_encoding_time/1000)} fps")

del rgb, depth, rgbd, output
# Out:
# Sample 100/100 - Avg. encoding time: 214.02401745319366 ms
#
# ** QUANTIZED se_resnet50 METRICS (CPU) **
# Avg. encoding time: 214.02401745319366 ms
# Avg. throughput: 4.672372810769692 fps
